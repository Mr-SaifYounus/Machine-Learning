# %%
# !pip install matplotlib
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# #Step 1:Generating synthetic data

# %%
#generate synthetic data for example
np.random.seed(0)
hours_studied=np.random.uniform(0,10,100)
exam_scores=50+5*hours_studied+np.random.normal(0,2,100)
print("Studied hours :",hours_studied,)
print("="*50)
print("The type of studied hours",type(hours_studied))
print("="*50)
print("Exam Scores are :",exam_scores)
print("="*50)
print("Type of Exam scores",type(exam_scores))
# Out:
# Studied hours : [5.48813504 7.15189366 6.02763376 5.44883183 4.23654799 6.45894113
#  4.37587211 8.91773001 9.63662761 3.83441519 7.91725038 5.2889492
#  5.68044561 9.25596638 0.71036058 0.871293   0.20218397 8.32619846
#  7.78156751 8.70012148 9.78618342 7.99158564 4.61479362 7.80529176
#  1.18274426 6.39921021 1.43353287 9.44668917 5.21848322 4.1466194
#  2.64555612 7.74233689 4.56150332 5.68433949 0.187898   6.17635497
#  6.12095723 6.16933997 9.43748079 6.81820299 3.59507901 4.37031954
#  6.97631196 0.60225472 6.66766715 6.7063787  2.10382561 1.28926298
#  3.15428351 3.63710771 5.7019677  4.38601513 9.88373838 1.02044811
#  2.08876756 1.61309518 6.53108325 2.53291603 4.66310773 2.44425592
#  1.58969584 1.10375141 6.56329589 1.38182951 1.96582362 3.68725171
#  8.2099323  0.97101276 8.37944907 0.96098408 9.76459465 4.68651202
#  9.76761088 6.0484552  7.39263579 0.39187792 2.82806963 1.20196561
#  2.96140198 1.18727719 3.17983179 4.14262995 0.64147496 6.92472119
# ...

# %% [markdown]
# #Step2: Converting synthetic data in dataframe for columns

# %%
import pandas as pd
data=pd.DataFrame({"Hours Studied":hours_studied,"Exam Scores":exam_scores})

# %%
data.head(100)
# Out:
#     Hours Studied  Exam Scores
# 0        5.488135    75.110376
# 1        7.151894    87.561121
# 2        6.027634    81.069494
# 3        5.448832    74.171672
# 4        4.236548    74.159244
# ..            ...          ...
# 95       1.831914    60.522757
# 96       5.865129    77.718827
# 97       0.201075    49.626278
# 98       8.289400    90.535936
# 99       0.046955    50.269732
#
# [100 rows x 2 columns]

# %% [markdown]
# #Step 3:Splitting data for training and testing

# %%
#split the data into training and testing (80%training,20%testing)
x=data[["Hours Studied"]]
y=data[["Exam Scores"]]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_test)
print("="*50)
print("Length of x test is",len(x_test))
print(y_test,len(y_test))
# Out:
#     Hours Studied
# 83       6.924721
# 53       1.020448
# 70       9.764595
# 45       6.706379
# 44       6.667667
# 39       6.818203
# 22       4.614794
# 80       3.179832
# 10       7.917250
# 0        5.488135
# 18       7.781568
# 30       2.645556
# 73       6.048455
# 33       5.684339
# 90       3.185690
# 4        4.236548
# 76       2.828070
# 77       1.201966
# 12       5.680446
# 31       7.742337
# ...
# Length of x test is 20
#     Exam Scores
# 83    84.798708
# 53    55.165902
# 70    98.686490
# 45    83.232624
# 44    81.949200
# 39    85.935428
# 22    70.532998
# 80    64.903094
# 10    88.779898
# 0     75.110376
# 18    89.161662
# 30    66.962899
# 73    78.589399
# 33    82.241827
# 90    67.770165
# 4     74.159244
# 76    66.393620
# 77    53.849965
# 12    78.818778
# 31    90.523774 20

# %%
print(y_test,"\n","\n",len(y_test))
print(x_test.ndim)
# Out:
#     Exam Scores
# 83    84.798708
# 53    55.165902
# 70    98.686490
# 45    83.232624
# 44    81.949200
# 39    85.935428
# 22    70.532998
# 80    64.903094
# 10    88.779898
# 0     75.110376
# 18    89.161662
# 30    66.962899
# 73    78.589399
# 33    82.241827
# 90    67.770165
# 4     74.159244
# 76    66.393620
# 77    53.849965
# 12    78.818778
# 31    90.523774
#
#  20

# %%
print(x_train)
print(y_train)
# Out:
#     Hours Studied
# 55       1.613095
# 88       5.759465
# 26       1.433533
# 42       6.976312
# 69       0.960984
# ..            ...
# 60       1.589696
# 71       4.686512
# 14       0.710361
# 92       1.317979
# 51       4.386015
#
# [80 rows x 1 columns]
#     Exam Scores
# 55    59.418342
# 88    81.173384
# 26    56.340426
# 42    85.478036
# 69    53.881751
# ..          ...
# 60    54.965964
# 71    76.859246
# 14    54.264536
# 92    58.303554
# 51    73.008574
#
# [80 rows x 1 columns]

# %% [markdown]
# #Step 4: Create ansd train a linear regression model

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #Step 5: MODEL EVALUATION

# %%
#MAKE PREDICTIONS ON TESTING DATA
y_pred=model.predict(x_test)

# %%
#Calculate mean squared error (MSE) between the two variables and predicted values
mse=mean_squared_error(y_test,y_pred)
#calculate the (R^2) rsquare scored between true values and predicted values
r2=r2_score(y_test,y_pred)
#computting mean squared error with formatting
print(f"Mean squared error:{mse:.2f}")
#print(r squared value with formatting)
print(f"R squared: {mse:.2f}")
# Out:
# Mean squared error:3.67
# R squared: 3.67

# %%
x_test = x_test.to_numpy().reshape(-1)
y_test = y_test.to_numpy().reshape(-1)
y_pred = y_pred.to_numpy().reshape(-1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 3
#       1 x_test = x_test.to_numpy().reshape(-1)
#       2 y_test = y_test.to_numpy().reshape(-1)
# ----> 3 y_pred = y_pred.to_numpy().reshape(-1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_numpy'

# %%
model=pd.DataFrame({"X-TEST": x_test,"Y-TEST":y_test,"Y-PREDICT":y_pred})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 model=pd.DataFrame({"X-TEST": x_test,"Y-TEST":y_test,"Y-PREDICT":y_pred})
#
# File c:\Users\Z\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...
